# %%
import pandas as pd
import numpy as np

# %%
electoralVotes = pd.read_csv('voting-weights/data/2016ElectoralVotesLocal.csv')
stateVotes = pd.read_csv('voting-weights/data/state-votes.csv')

# %%
stateVotes = pd.read_csv('voting-weights/data/state-votes.csv')

# %%
statePopulations = pd.read_csv('voting-weights/data/StatePopulations.csv')

# %%
stateVotes
# Out:
#                    State    Trump  Clinton
# 0                Alabama  1306925   718084
# 1                 Alaska   116454   163387
# 2                Arizona   972900   888374
# 3               Arkansas   677904   378729
# 4             California  2970470  5488776
# 5               Colorado  1136354  1208095
# 6            Connecticut   637919   823360
# 7               Delaware   185103   235581
# 8   District of Columbia   282830    12723
# 9                Florida  4605515  4485745
# 10               Georgia  2068623  1837300
# 11                Hawaii   128815   266827
# 12                 Idaho   407199   189677
# 13              Illinois  2118179  2977498
# 14               Indiana  1556220  1031953
# 15                  Iowa   798923   650790
# 16                Kansas   656009   414788
# 17              Kentucky  1202942   628834
# 18             Louisiana  1178004   779535
# 19                 Maine   334838   354873
# 20              Maryland   873646  1497951
# ...
