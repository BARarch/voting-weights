# %%
import pandas as pd
import numpy as np

# %%
vt = pd.read_csv(r'data/state-weights.csv')

# %%
vt
# Out:
#     Unnamed: 0                 State  2018 Population    Trump  Clinton  \
# 0            0               Alabama          4888949  1306925   718084
# 1            1                Alaska           738068   116454   163387
# 2            2               Arizona          7123898   972900   888374
# 3            3              Arkansas          3020327   677904   378729
# 4            4            California         39776830  2970470  5488776
# 5            5              Colorado          5684203  1136354  1208095
# 6            6           Connecticut          3588683   637919   823360
# 7            7              Delaware           971180   185103   235581
# 8            8  District of Columbia           703608   282830    12723
# 9            9               Florida         21312211  4605515  4485745
# 10          10               Georgia         10545138  2068623  1837300
# 11          11                Hawaii          1426393   128815   266827
# ...

# %%
df = vt[['State', 'Trump', 'Clinton', '2018 Population', 'Total Votes', 'Winning Votes', 'Necessary Votes', 'Excess Votes']]

# %%
df
# Out:
#                    State    Trump  Clinton  2018 Population  Total Votes  \
# 0                Alabama  1306925   718084          4888949      2025009
# 1                 Alaska   116454   163387           738068       279841
# 2                Arizona   972900   888374          7123898      1861274
# 3               Arkansas   677904   378729          3020327      1056633
# 4             California  2970470  5488776         39776830      8459246
# 5               Colorado  1136354  1208095          5684203      2344449
# 6            Connecticut   637919   823360          3588683      1461279
# 7               Delaware   185103   235581           971180       420684
# 8   District of Columbia   282830    12723           703608       295553
# 9                Florida  4605515  4485745         21312211      9091260
# 10               Georgia  2068623  1837300         10545138      3905923
# 11                Hawaii   128815   266827          1426393       395642
# ...

# %%
df.to_csv(r'breakdownSketch/data/vote-breakdown.csv')
